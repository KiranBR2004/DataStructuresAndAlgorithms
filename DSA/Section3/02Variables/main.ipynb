# %% [markdown]
# ## Variables In Python

# %%
a=100

# %%
## Declaring and Assigning Variables

age=21
height=6.2
name="kiran"
is_student=True

##printing variables

print("age:",age)
print("Height:",height)
print("Name:",name)
# Out:
# age: 21
# Height: 6.2
# Name: kiran

# %%
## Naming convention
## Variable name should be discriptive
## they must start with an letter or '_' and it contains letters,numbers,and underscroes
## Variables name case sensitive

## valid variable name

first_name="kiran"
last_name="br"

# %%
## invalid variable name

#2age=21
#first-name="kiran"
#@name="kiran"
# Out:
#   Cell In[6], line 5
#     @name="kiran"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## Case sensitivity

name="kiran"
name==Name
# Out:
# False
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Program Files/Python313/python.exe" -m pip install ipykernel -U --user --force-reinstall'
# Running cells with 'Python 3.13.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Program Files/Python313/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
## understanding variable type
## python is dynamicaly typed,type of a variable determined the runtime

age=21 #int
height=6.2 #flot
name="kiran" #str
is_student=True #boll

print(type(age))
# Out:
# <class 'int'>

# %%
## Type checking and conversion

type(height)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 ## Type checking and conversion
# ----> 3 type(height)
#
# NameError: name 'height' is not defined

# %%
age=21
print(type(age))

# type conversion

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 21
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name='kiran'
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 name='kiran'
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'kiran'

# %%
height=6.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 6.0

# %%
## dynamic typing
## python allows the type of a variable to change as the program executes

var=10 #int
print(var, type(var))

var='hello'
print(var, type(var))

var=6.1
print(var, type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 6.1 <class 'float'>

# %%
## input
age=int(input("what is the age"))
print(age, type(age))
# Out:
# 21 <class 'int'>

# %%
## simple calculater

num1=float(input("Enter a first number : "))
num2= float(input("Enter a second number : "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum: ", sum)
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: ",quotient)
# Out:
# Sum:  30.0
# Difference:  -10.0
# Product:  200.0
# Quotient:  0.5
