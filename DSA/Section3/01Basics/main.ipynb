# %% [markdown]
# ## Syntax And Semantices in Python

# %%
## basic code
print(1+2)
# Out:
# 3

# %% [markdown]
# # Example

# %%
## basic code
print("hello world")
# Out:
# hello world

# %%
## basic syntax rule
## python is case sensitivity

name="kiran"
Name="Santhosh"

print(name)
print(Name)
# Out:
# kiran
# Santhosh

# %%
## indentation

age=21
if age>20:
    print(age)

print(age)
# Out:
# 21
# 21

# %%
## this is single line command

print("welcom to python")
# Out:
# welcom to python

# %%
## line continuation
## use backslash(\) to continue the statement in next line

total=1+2+3+4+5+6+\
       5+6+7
print(total)
# Out:
# 39

# %%
## multiple statement in a single line

x=5;y=10;z=x+y;
print(z)
# Out:
# 15

# %%
## understand semnatics in python
# variable assigenment

age=21 ##age is an integer
name="Kiran" ##name is an string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type inference
variable=10
print(type(variable))
variable="kiran"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#indentation error
age=21
if age>20:
print(age)
# Out:
#   Cell In[24], line 4
#     print(age)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
## Name error

a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 ## Name error
# ----> 3 a=b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation

if True:
    print("corect indentation")
    if False:
        print("this ont print")
    print("this will print")
print("outside if block")
# Out:
# corect indentation
# this will print
# outside if block
