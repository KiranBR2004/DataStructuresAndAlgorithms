# %% [markdown]
# ## DataTypes In Python

# %%
# Integer example

age=21
type(age)
# Out:
# int

# %%
# Floating Point Datatype

height=6.12
print(height)
print(type(height))
# Out:
# 6.12
# <class 'float'>

# %%
# String datatype Example

name='kiran'
print(name)
print(type(name))
# Out:
# kiran
# <class 'str'>

# %%
# bollean datatype example

is_true=True
type(is_true)
# Out:
# bool

# %%
a=10
b=10
a==b
# Out:
# True

# %%
# comman errors

result=("hello"+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # comman errors
# ----> 3 result=("hello"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
result=("hello" +str(5))
print(result)
# Out:
# hello5
